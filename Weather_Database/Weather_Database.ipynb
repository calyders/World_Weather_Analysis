# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(-48.37636324516808, -26.33004803817343), (-78.53551013790023, -7.400063120571076), (12.800439371174562, -79.40896117484874), (40.07755722523879, 75.29532696149963), (58.81452270275261, -76.75687109372176), (53.75658354334843, 49.281839967008125), (15.485487750583744, 93.33717590562168), (67.69711805031346, 42.10008552804291), (86.37292051794739, 149.02950465705663), (-62.223214804888414, -21.671456979864047), (-60.25153105386703, 166.12610497332543), (89.18596359061439, 21.350051508079815), (-26.910311686429857, 73.96062536915738), (-45.210558768291236, 92.22663927600877), (-77.92661328909568, 34.04736583530152), (-68.45417267909775, 8.969974100427834), (-18.205391416660518, -12.404621332473027), (-59.27120842500415, 51.468746633020544), (-80.36434147143967, 4.723178895895273), (77.47251862829654, -162.90187196434957), (43.975811332898644, 23.195846812956432), (-13.908834297548253, -162.17591804492287), (84.48417462157983, -37.97650758067755), (-61.28338675308264, -25.868811880737155), (-82.40564024421545, -58.96373160660133), (-50.292457469263624, 32.979841430990575), (30.49247871734771, -125.67479937355165), (-83.26011557720699, -44.870592734100825), (-64.82258146360036, -170.1864543033428), (-37.43166593842308, -157.8774938760829), (-35.50309765812384, -32.35478585691598), (56.40378004513005, 163.43314730612872), (45.93976335179099, 127.93152978480094), (15.837631788433768, 43.54065109436493), (-58.65229604843567, 118.23682159857037), (-72.98074933750591, -99.9198704650964), (86.57016186183256, 27.75233667675562), (67.31404278811993, -23.985427368966185), (0.49571434564104777, 93.29719183047717), (-75.18100961069854, 176.06920937844626), (11.698925370587972, 169.45008734924573), (86.64443538419866, 50.231921543288706), (3.6227563086526686, -58.18227565679781), (-30.21684149367291, -146.50455336838633), (-19.63483798466899, 0.31680062779116724), (-79.79897411727593, 162.6761342481509), (59.607945445681764, -27.31424586596711), (6.218803095343333, 164.2781242178648), (48.64127944774495, -111.01575051354945), (-75.62938900173422, 122.83714345474624), (53.23488504415553, -82.4932673259211), (-82.99602745855981, 147.80255375473604), (17.427118450475447, -169.67722686330183), (-54.2701253968206, -22.52019229263223), (59.21899811782555, 143.92242038338486), (-67.80641219441208, 124.88558089790592), (73.34537499416086, 95.49528919141005), (-66.23290793614143, 141.1842157936971), (-8.945767643629424, -174.05243973984906), (27.265378340191432, 96.56685122741891), (35.823340519659, -128.83937055457847), (60.6081592169169, -72.82277260500675), (-22.838724815824875, 87.99914683545586), (72.69201969549616, 27.731699431864286), (29.843567073965005, -50.67690879765826), (-2.3484028207406027, 72.32585933120819), (6.048065645473244, -162.9742538940093), (45.08701294388578, -46.45126052633489), (-2.194805464448109, -29.251787034951008), (-58.02497187513654, -172.3562239663071), (-66.89289109094774, 137.10734753393183), (11.928655418921664, 75.7052679764615), (-4.811045203357764, 164.18190321227587), (74.53668775005914, 50.76229465573246), (-51.26773789574973, -135.69999379516446), (76.51032236571012, -135.52119999120728), (-34.45653803807548, 151.77846858487237), (-60.497649131016246, -118.53386036484632), (-45.3493055392598, -29.01234515063365), (63.743065099352066, 14.30841075900318), (26.067988246448365, 23.934011004056742), (-28.946390030556557, 148.54542292141417), (-56.35999265123786, 6.326991016579399), (-55.88709981217736, -163.21416040663837), (-56.588324744213956, 154.52237248109128), (-89.72597612076197, 89.22025650305761), (82.26508688350069, -131.0282139509485), (48.00341373578317, -150.4756555497042), (-79.87443792669966, -9.131198532545596), (23.55832515883627, 165.728651746156), (2.208786843302306, 15.72271107277598), (-4.4095578346920234, 70.28768352468072), (17.16467337307394, 159.0294818518804), (71.35233249592093, -42.74183057289676), (-12.153091232075496, 178.08218073128813), (-80.85844484234875, -12.163421784970495), ( ...

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | san andres
# Processing Record 4 of Set 1 | kashi
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | khryashchevka
# Processing Record 7 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 1 | ostrovnoy
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | seaca de camp
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | lompoc
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 1 | binzhou
# Processing Record 28 of Set 1 | bajil
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 1 | meulaboh
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | lethem
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | olafsvik
# Processing Record 39 of Set 1 | great falls
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | okhotsk
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 1 | tezu
# Processing Record 48 of Set 1 | ukiah
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | mehamn
# Processing Record 2 of Set 2 | saint george
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | touros
# Processing Record 7 of Set 2 | nadapuram
# Processing Record 8 of Set 2 | auki
# Processing Record 9 of Set 2 | rikitea
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | sydney
# Processing Record 12 of Set 2 | ostersund
# Processing Record 13 of Set 2 | jalu
# Processing Record 14 of Set 2 | moree
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | ouesso
# Processing Record 18 of Set 2 | asau
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | pahalgam
# Processing Record 22 of Set 2 | tual
# Processing Record 23 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | vanimo
# Processing Record 26 of Set 2 | adrar
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | narsaq
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | lavrentiya
# Processing Record 31 of Set 2 | lima
# Processing Record 32 of Set 2 | esso
# Processing Record 33 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 2 | berea
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | zharkent
# Processing Record 37 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 2 | jinchang
# Processing Record 39 of Set 2 | baracoa
# Processing Record 40 of Set 2 | hanzhong
# Processing Record 41 of Set 2 | khotynets
# Processing Record 42 of Set 2 | leshukonskoye
# Processing Record 43 of Set 2 | emba
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | valparaiso
# Processing Record 46 of Set 2 | kunagota
# Processing Record 47 of Set 2 | coro
# Processing Record 48 of Set 2 | maniitsoq
# Processing Record 49 of Set 2 | prestea
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | vila velha
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | micheweni
# Processing Record 4 of Set 3 | mpanda
# Processing Record 5 of Set 3 | cabadiangan
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | caravelas
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | spornoye
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | isangel
# Processing Record 13 of Set 3 | empalme
# Processing Record 14 of Set 3 | milkovo
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | afua
# Processing Record 19 of Set 3 | krasnoselkup
# Processing Record 20 of Set 3 | wanganui
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | kruisfontein
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | aykhal
# Processing Record 25 of Set 3 | pevek
# Processing Record 26 of Set 3 | gardan diwal
# City not found. Skipping...
# Processing Record 27 of Set 3 | westport
# Processing Record 28 of Set 3 | ponta do sol
# Processing Record 29 of Set 3 | havre-saint-pierre
# Processing Record 30 of Set 3 | malko tarnovo
# Processing Record 31 of Set 3 | mokhsogollokh
# Processing Record 32 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 33 of Set 3 | bud
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | rurrenabaque
# Processing Record 36 of Set 3 | maxixe
# Processing Record 37 of Set 3 | airai
# Processing Record 38 of Set 3 | husavik
# Processing Record 39 of Set 3 | kyra
# Processing Record 40 of Set 3 | te anau
# Processing Record 41 of Set 3 | chulym
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | veraval
# Processing Record 44 of Set 3 | puerto escondido
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | saint anthony
# Processing Record 47 of Set 3 | kavaratti
# Processing Record 48 of Set 3 | carutapera
# Processing Record 49 of Set 3 | tres lagoas
# Processing Record 50 of Set 3 | castro
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | san patricio
# Processing Record 3 of Set 4 | proletarskiy
# Processing Record 4 of Set 4 | dauriya
# Processing Record 5 of Set 4 | la uribe
# City not found. Skipping...
# Processing Record 6 of Set 4 | aripuana
# Processing Record 7 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 9 of Set 4 | makueni
# Processing Record 10 of Set 4 | salinopolis
# Processing Record 11 of Set 4 | aklavik
# Processing Record 12 of Set 4 | tuatapere
# Processing Record 13 of Set 4 | twentynine palms
# Processing Record 14 of Set 4 | kuloy
# Processing Record 15 of Set 4 | rio grande
# Processing Record 16 of Set 4 | saint-joseph
# Processing Record 17 of Set 4 | coroico
# Processing Record 18 of Set 4 | elat
# Processing Record 19 of Set 4 | vysokogornyy
# Processing Record 20 of Set 4 | baykit
# Processing Record 21 of Set 4 | santa cruz
# Processing Record 22 of Set 4 | hamilton
# Processing Record 23 of Set 4 | tutoia
# Processing Record 24 of Set 4 | batagay
# Processing Record 25 of Set 4 | turukhansk
# Processing Record 26 of Set 4 | arosa
# Processing Record 27 of Set 4 | faya
# Processing Record 28 of Set 4 | laguna
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | rute
# Processing Record 31 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 4 | stornoway
# Processing Record 33 of Set 4 | zyryanka
# Processing Record 34 of Set 4 | dunedin
# Processing Record 35 of Set 4 | canutama
# Processing Record 36 of Set 4 | pisco
# Processing Record 37 of Set 4 | ancud
# Processing Record 38 of Set 4 | calama
# Processing Record 39 of Set 4 | marsa matruh
# Processing Record 40 of Set 4 | itoman
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | khandyga
# Processing Record 43 of Set 4 | smolenka
# Processing Record 44 of Set 4 | bayan
# Processing Record 45 of Set 4 | dharchula
# Processing Record 46 of Set 4 | briancon
# Processing Record 47 of Set 4 | aksum
# Processing Record 48 of Set 4 | cameron park
# Processing Record 49 of Set 4 | mackay
# Processing Record 50 of Set 4 | upernavik
# Processing Record 1 of Set 5 | nikolskoye
# Processing Record 2 of Set 5 | grindavik
# Processing Record 3 of Set 5 | mandiana
# Processing Record 4 of Set 5 | broken hill
# Processing Record 5 of Set 5 | mandalgovi
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 5 | tefe
# Processing Record 10 of Set 5 | biak
# Processing Record 11 of Set 5 | fort nelson
# Processing Record 12 of Set 5 | jay
# Processing Record 13 of Set 5 | ilulissat
# Processing Record 14 of Set 5 | waipawa
# Processing Record 15 of Set 5 | berlevag
# Processing Record 16 of Set 5 | bac lieu
# Processing Record 17 of Set 5 | lebu
# Processing Record 18 of Set 5 | shingu
# Processing Record 19 of Set 5 | charters towers
# Processing Record 20 of Set 5 | mayumba
# Processing Record 21 of Set 5 | ialibu
# Processing Record 22 of Set 5 | port moresby
# Processing Record 23 of Set 5 | srednekolymsk
# Processing Record 24 of Set 5 | mendi
# Processing Record 25 of Set 5 | dillon
# Processing Record 26 of Set 5 | smyrna
# Processing Record 27 of Set 5 | bambanglipuro
# Processing Record 28 of Set 5 | solnechnyy
# Processing Record 29 of Set 5 | harper
# Processing Record 30 of Set 5 | afgoye
# City not found. Skipping...
# Processing Record 31 of Set 5 | marsh harbour
# Processing Record 32 of Set 5 | rehburg-loccum
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | moose factory
# Processing Record 35 of Set 5 | luanda
# Processing Record 36 of Set 5 | awbari
# Processing Record 37 of Set 5 | kununurra
# Processing Record 38 of Set 5 | brownwood
# Processing Record 39 of Set 5 | kautokeino
# Processing Record 40 of Set 5 | nanortalik
# Processing Record 41 of Set 5 | atar
# Processing Record 42 of Set 5 | severodvinsk
# Processing Record 43 of Set 5 | halifax
# Processing Record 44 of Set 5 | naze
# Processing Record 45 of Set 5 | port hardy
# Processing Record 46 of Set 5 | povoa de lanhoso
# Processing Record 47 of Set 5 | cabo san lucas
# Processing Record 48 of Set 5 | thompson
# Processing Record 49 of Set 5 | zhuhai
# Processing Record 50 of Set 5 | keta
# Processing Record 1 of Set 6 | severo-kurilsk
# Processing Record 2 of Set 6 | chongwe
# Processing Record 3 of Set 6 | rosarito
# Processing Record 4 of Set 6 | eureka
# Processing Record 5 of Set 6 | leh
# Processing Record 6 of Set 6 | saldanha
# Processing Record 7 of Set 6 | kavieng
# Processing Record 8 of Set 6 | abnub
# Processing Record 9 of Set 6 | cortland
# Processing Record 10 of Set 6 | velyka bilozerka
# Processing Record 11 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 6 | katangli
# Processing Record 13 of Set 6 | esperance
# Processing Record 14 of Set 6 | calabozo
# Processing Record 15 of Set 6 | mount gambier
# Processing Record 16 of Set 6 | qaanaaq
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | umm ruwabah
# City not found. Skipping...
# Processing Record 19 of Set 6 | shache
# Processing Record 20 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 21 of Set 6 | dikson
# Processing Record 22 of Set 6 | zhanaozen
# Processing Record 23 of Set 6 | tambovka
# Processing Record 24 of Set 6 | san jeronimo
# Processing Record 25 of Set 6 | manggar
# Processing Record 26 of Set 6 | concordia
# Processing Record 27 of Set 6 | biloela
# Processing Record 28 of Set 6 | constitucion
# Processing Record 29 of Set 6 | havoysund
# Processing Record 30 of Set 6 | tigil
# Processing Record 31 of Set 6 | karratha
# Processing Record 32 of Set 6 | bloemfontein
# Processing Record 33 of Set 6 | san pedro de macoris
# Processing Record 34 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | parvatsar
# Processing Record 36 of Set 6 | port hedland
# Processing Record 37 of Set 6 | kasongo-lunda
# Processing Record 38 of Set 6 | araouane
# Processing Record 39 of Set 6 | riyadh
# Processing Record 40 of Set 6 | mapiri
# Processing Record 41 of Set 6 | santa rosa
# Processing Record 42 of Set 6 | sisimiut
# Processing Record 43 of Set 6 | merauke
# Processing Record 44 of Set 6 | challans
# Processing Record 45 of Set 6 | lorengau
# Processing Record 46 of Set 6 | viloco
# Processing Record 47 of Set 6 | iberia
# Processing Record 48 of Set 6 | svetlogorsk
# Processing Record 49 of Set 6 | inirida
# Processing Record 50 of Set 6 | kahului
# Processing Record 1 of Set 7 | smithers
# Processing Record 2 of Set 7 | randudongkal
# Processing Record 3 of Set 7 | nuuk
# Processing Record 4 of Set 7 | paulo ramos
# Processing Record 5 of Set 7 | raudeberg
# Processing Record 6 of Set 7 | ken caryl
# Processing Record 7 of Set 7 | ribeira grande
# Processing Record 8 of Set 7 | candido mendes
# Processing Record 9 of Set 7 | oda
# Processing Record 10 of Set 7 | ajdabiya
# Processing Record 11 of Set 7 | araguaina
# Processing Record 12 of Set 7 | harpanahalli
# Processing Record 13 of Set 7 | souillac
# Processing Record 14 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 7 | lockhart
# Processing Record 16 of Set 7 | ampanihy
# Processing Record 17 of Set 7 | suntar
# Processing Record 18 of Set 7 | vostok
# Processing Record 19 of Set 7 | anloga
# Processing Record 20 of Set 7 | roebourne
# Processing Record 21 of Set 7 | santa maria
# Processing Record 22 of Set 7 | vila franca do campo
# Processing Record 23 of Set 7 | tsaratanana
# Processing Record 24 of Set 7 | podyuga
# Processing Record 25 of Set 7 | acajutla
# Processing Record 26 of Set 7 | cockburn town
# Processing Record 27 of Set 7 | quatre cocos
# Processing Record 28 of Set 7 | jumla
# Processing Record 29 of Set 7 | norman wells
# Processing Record 30 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 7 | sartell
# Processing Record 32 of Set 7 | grajewo
# Processing Record 33 of Set 7 | andenes
# Processing Record 34 of Set 7 | buenos aires
# Processing Record 35 of Set 7 | mponela
# Processing Record 36 of Set 7 | datong
# Processing Record 37 of Set 7 | rawson
# Processing Record 38 of Set 7 | novaya igirma
# Processing Record 39 of Set 7 | ola
# Processing Record 40 of Set 7 | sao joao da barra
# Processing Record 41 of Set 7 | cayenne
# Processing Record 42 of Set 7 | parkes
# Processing Record 43 of Set 7 | herat
# Processing Record 44 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 7 | bilma
# Processing Record 46 of Set 7 | sao gabriel da cachoeira
# Processing Record 47 of Set 7 | sukumo
# Processing Record 48 of Set 7 | sitka
# Processing Record 49 of Set 7 | chlorakas
# Processing Record 50 of Set 7 | san vicente
# Processing Record 1 of Set 8 | pitimbu
# Processing Record 2 of Set 8 | sinnamary
# Processing Record 3 of Set 8 | qinzhou
# Processing Record 4 of Set 8 | baft
# Processing Record 5 of Set 8 | sioux lookout
# Processing Record 6 of Set 8 | qasigiannguit
# Processing Record 7 of Set 8 | karpathos
# Processing Record 8 of Set 8 | celestun
# Processing Record 9 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 8 | san quintin
# Processing Record 11 of Set 8 | male
# Processing Record 12 of Set 8 | talnakh
# Processing Record 13 of Set 8 | broome
# Processing Record 14 of Set 8 | karaton
# Processing Record 15 of Set 8 | guamuchil
# Processing Record 16 of Set 8 | udachnyy
# Processing Record 17 of Set 8 | hami
# Processing Record 18 of Set 8 | ugoofaaru
# Processing Record 19 of Set 8 | high rock
# Processing Record 20 of Set 8 | hendek
# Processing Record 21 of Set 8 | yerbogachen
# Processing Record 22 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 23 of Set 8 | taltal
# Processing Record 24 of Set 8 | kloulklubed
# Processing Record 25 of Set 8 | salalah
# Processing Record 26 of Set 8 | ocampo
# Processing Record 27 of Set 8 | timberlake
# Processing Record 28 of Set 8 | coihaique
# Processing Record 29 of Set 8 | zavetnoye
# Processing Record 30 of Set 8 | kabanjahe
# Processing Record 31 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 32 of Set 8 | san luis
# Processing Record 33 of Set 8 | twin falls
# Processing Record 34 of Set 8 | juruti
# Processing Record 35 of Set 8 | mayo
# Processing Record 36 of Set 8 | bilibino
# Processing Record 37 of Set 8 | vardo
# Processing Record 38 of Set 8 | unguia
# Processing Record 39 of Set 8 | grand gaube
# Processing Record 40 of Set 8 | banjar
# Processing Record 41 of Set 8 | bathsheba
# Processing Record 42 of Set 8 | huarmey
# Processing Record 43 of Set 8 | maibong
# Processing Record 44 of Set 8 | puhja
# Processing Record 45 of Set 8 | floro
# Processing Record 46 of Set 8 | wajir
# Processing Record 47 of Set 8 | kiunga
# Processing Record 48 of Set 8 | vilyuysk
# Processing Record 49 of Set 8 | padang
# Processing Record 50 of Set 8 | saskylakh
# Processing Record 1 of Set 9 | lhokseumawe
# Processing Record 2 of Set 9 | sucre
# Processing Record 3 of Set 9 | hearst
# Processing Record 4 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 9 | dalianwan
# Processing Record 6 of Set 9 | flin flon
# Processing Record 7 of Set 9 | guarabira
# Processing Record 8 of Set 9 | shelburne
# Processing Record 9 of Set 9 | cutzamala
# City not found. Skipping...
# Processing Record 10 of Set 9 | itarema
# Processing Record 11 of Set 9 | russkaya polyana
# Processing Record 12 of Set 9 | norsup
# Processing Record 13 of Set 9 | tecoanapa
# Processing Record 14 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 9 | tessalit
# Processing Record 16 of Set 9 | dergachi
# Processing Record 17 of Set 9 | kasama
# Processing Record 18 of Set 9 | okha
# Processing Record 19 of Set 9 | sao joao de pirabas
# Processing Record 20 of Set 9 | toyoshina
# Processing Record 21 of Set 9 | west odessa
# Processing Record 22 of Set 9 | san carlos de bariloche
# Processing Record 23 of Set 9 | coquimbo
# Processing Record 24 of Set 9 | fortuna
# Processing Record 25 of Set 9 | rocha
# Processing Record 26 of Set 9 | crotone
# Processing Record 27 of Set 9 | kalangala
# Processing Record 28 of Set 9 | tura
# Processing Record 29 of Set 9 | kendal
# Processing Record 30 of Set 9 | beroroha
# Processing Record 31 of Set 9 | provost
# Processing Record 32 of Set 9 | acari
# Processing Record 33 of Set 9 | sobolevo
# Processing Record 34 of Set 9 | bundaberg
# Processing Record 35 of Set 9 | boende
# Processing Record 36 of Set 9 | alofi
# Processing Record 37 of Set 9 | praia
# Processing Record 38 of Set 9 | timbiqui
# Processing Record 39 of Set 9 | matias romero
# Processing Record 40 of Set 9 | pangkalanbuun
# Processing Record 41 of Set 9 | dongsheng
# Processing Record 42 of Set 9 | el faiyum
# City not found. Skipping...
# Processing Record 43 of Set 9 | panormos
# Processing Record 44 of Set 9 | mineiros
# Processing Record 45 of Set 9 | portland
# Processing Record 46 of Set 9 | ca mau
# Processing Record 47 of Set 9 | general pico
# Processing Record 48 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 49 of Set 9 | tubuala
# Processing Record 50 of Set 9 | katsuura
# Processing Record 1 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 10 | sydney mines
# Processing Record 3 of Set 10 | kharp
# Processing Record 4 of Set 10 | waingapu
# Processing Record 5 of Set 10 | miranda
# Processing Record 6 of Set 10 | kawalu
# Processing Record 7 of Set 10 | ryotsu
# Processing Record 8 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 10 | itanhem
# Processing Record 10 of Set 10 | san cristobal
# Processing Record 11 of Set 10 | ixtapa
# Processing Record 12 of Set 10 | teluk nibung
# Processing Record 13 of Set 10 | aden
# Processing Record 14 of Set 10 | port lincoln
# Processing Record 15 of Set 10 | niamey
# Processing Record 16 of Set 10 | salta
# Processing Record 17 of Set 10 | salisbury
# Processing Record 18 of Set 10 | anadyr
# Processing Record 19 of Set 10 | muros
# Processing Record 20 of Set 10 | moussoro
# Processing Record 21 of Set 10 | umm lajj
# Processing Record 22 of Set 10 | kilcullen
# Processing Record 23 of Set 10 | langsa
# Processing Record 24 of Set 10 | lata
# Processing Record 25 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 10 | magaria
# Processing Record 27 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 10 | pauini
# Processing Record 29 of Set 10 | mamakan
# Processing Record 30 of Set 10 | batemans bay
# Processing Record 31 of Set 10 | cacule
# Processing Record 32 of Set 10 | paita
# Processing Record 33 of Set 10 | klaksvik
# Processing Record 34 of Set 10 | arona
# Processing Record 35 of Set 10 | cap malheureux
# Processing Record 36 of Set 10 | vestmannaeyjar
# Processing Record 37 of Set 10 | sorong
# Processing Record 38 of Set 10 | sakakah
# Processing Record 39 of Set 10 | baghdad
# Processing Record 40 of Set 10 | calvinia
# Processing Record 41 of Set 10 | bonthe
# Processing Record 42 of Set 10 | sharlyk
# Processing Record 43 of Set 10 | myaundzha
# Processing Record 44 of Set 10 | moron
# Processing Record 45 of Set 10 | nelson bay
# Processing Record 46 of Set 10 | necochea
# Processing Record 47 of Set 10 | avera
# Processing Record 48 of Set 10 | mahebourg
# Processing Record 49 of Set 10 | biltine
# Processing Record 50 of Set 10 | maralal
# Processing Record 1 of Set 11 | bukene
# Processing Record 2 of Set 11 | dispur
# Processing Record 3 of Set 11 | san ignacio
# Processing Record 4 of Set 11 | tucumcari
# Processing Record 5 of Set 11 | pordim
# Processing Record 6 of Set 11 | mondovi
# Processing Record 7 of Set 11 | carauari
# Processing Record 8 of Set 11 | bageshwar
# Processing Record 9 of Set 11 | george
# Processing Record 10 of Set 11 | tesalia
# Processing Record 11 of Set 11 | cibitoke
# Processing Record 12 of Set 11 | kotovo
# Processing Record 13 of Set 11 | ketchikan
# Processing Record 14 of Set 11 | miles city
# Processing Record 15 of Set 11 | ambilobe
# Processing Record 16 of Set 11 | codrington
# Processing Record 17 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 11 | hualmay
# Processing Record 19 of Set 11 | kristianstad
# Processing Record 20 of Set 11 | masaurhi
# Processing Record 21 of Set 11 | makhachkala
# Processing Record 22 of Set 11 | macara
# Processing Record 23 of Set 11 | burnie
# Processing Record 24 of Set 11 | cururupu
# Processing Record 25 of Set 11 | moskovskiy
# Processing Record 26 of Set 11 | zhigansk
# Processing Record 27 of Set 11 | yaan
# Processing Record 28 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 29 of Set 11 | sur
# Processing Record 30 of Set 11 | atbasar
# Processing Record 31 of Set 11 | songjianghe
# Processing Record 32 of Set 11 | zaranj
# Processing Record 33 of Set 11 | asuncion
# Processing Record 34 of Set 11 | asfi
# Processing Record 35 of Set 11 | kenai
# Processing Record 36 of Set 11 | yumen
# Processing Record 37 of Set 11 | nalut
# Processing Record 38 of Set 11 | coahuayana
# Processing Record 39 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 40 of Set 11 | yermekeyevo
# Processing Record 41 of Set 11 | inongo
# Processing Record 42 of Set 11 | shunyi
# Processing Record 43 of Set 11 | daru
# Processing Record 44 of Set 11 | beloha
# Processing Record 45 of Set 11 | nemuro
# Processing Record 46 of Set 11 | elko
# Processing Record 47 of Set 11 | flinders
# Processing Record 48 of Set 11 | namatanai
# Processing Record 49 of Set 11 | minot
# Processing Record 50 of Set 11 | paratinga
# Processing Record 1 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 12 | namibe
# Processing Record 3 of Set 12 | boralday
# Processing Record 4 of Set 12 | candoni
# Processing Record 5 of Set 12 | nyurba
# Processing Record 6 of Set 12 | muroto
# Processing Record 7 of Set 12 | presidencia roque saenz pena
# Processing Record 8 of Set 12 | yei
# Processing Record 9 of Set 12 | port angeles
# Processing Record 10 of Set 12 | la ronge
# Processing Record 11 of Set 12 | samdari
# Processing Record 12 of Set 12 | sudbury
# Processing Record 13 of Set 12 | puqi
# Processing Record 14 of Set 12 | vao
# Processing Record 15 of Set 12 | seoul
# Processing Record 16 of Set 12 | sabang
# Processing Record 17 of Set 12 | rameshki
# Processing Record 18 of Set 12 | whitecourt
# Processing Record 19 of Set 12 | praia da vitoria
# Processing Record 20 of Set 12 | guilin
# Processing Record 21 of Set 12 | saurimo
# Processing Record 22 of Set 12 | ducheng
# Processing Record 23 of Set 12 | laon
# Processing Record 24 of Set 12 | sao jose da coroa grande
# Processing Record 25 of Set 12 | zhezkazgan
# Processing Record 26 of Set 12 | launceston
# Processing Record 27 of Set 12 | buluang
# Processing Record 28 of Set 12 | nador
# Processing Record 29 of Set 12 | lasa
# Processing Record 30 of Set 12 | jardim
# Processing Record 31 of Set 12 | samarai
# Processing Record 32 of Set 12 | tongchuan
# Processing Record 33 of Set 12 | netanya
# Processing Record 34 of Set 12 | gushikawa
# Processing Record 35 of Set 12 | melipilla
# Processing Record 36 of Set 12 | mezhdurechenskiy
# Processing Record 37 of Set 12 | leningradskiy
# Processing Record 38 of Set 12 | matara
# Processing Record 39 of Set 12 | azare
# Processing Record 40 of Set 12 | fairbanks
# Processing Record 41 of Set 12 | margate
# Processing Record 42 of Set 12 | balikpapan
# Processing Record 43 of Set 12 | sibolga
# Processing Record 44 of Set 12 | prado
# Processing Record 45 of Set 12 | kilindoni
# Processing Record 46 of Set 12 | alexandria
# Processing Record 47 of Set 12 | san-pedro
# Processing Record 48 of Set 12 | tangshan
# Processing Record 49 of Set 12 | tautira
# Processing Record 50 of Set 12 | guaruja
# Processing Record 1 of Set 13 | komsomolskiy
# Processing Record 2 of Set 13 | sterling
# Processing Record 3 of Set 13 | jutai
# Processing Record 4 of Set 13 | christchurch
# Processing Record 5 of Set 13 | chumikan
# Processing Record 6 of Set 13 | camacha
# Processing Record 7 of Set 13 | hirosaki
# Processing Record 8 of Set 13 | mazurivka
# Processing Record 9 of Set 13 | wanaka
# Processing Record 10 of Set 13 | yongan
# Processing Record 11 of Set 13 | sangar
# Processing Record 12 of Set 13 | sabzevar
# Processing Record 13 of Set 13 | mumford
# Processing Record 14 of Set 13 | belyy yar
# Processing Record 15 of Set 13 | iskateley
# Processing Record 16 of Set 13 | poum
# Processing Record 17 of Set 13 | cap-aux-meules
# Processing Record 18 of Set 13 | saint-pierre
# Processing Record 19 of Set 13 | goderich
# Processing Record 20 of Set 13 | port blair
# Processing Record 21 of Set 13 | quebrangulo
# Processing Record 22 of Set 13 | mtama
# Processing Record 23 of Set 13 | richards bay
# Processing Record 24 of Set 13 | mbengwi
# Processing Record 25 of Set 13 | shagonar
# Processing Record 26 of Set 13 | kushima
# Processing Record 27 of Set 13 | makakilo city
# Processing Record 28 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 29 of Set 13 | mantua
# Processing Record 30 of Set 13 | evanston
# Processing Record 31 of Set 13 | tvoroyri
# Processing Record 32 of Set 13 | farrukhnagar
# Processing Record 33 of Set 13 | nantucket
# Processing Record 34 of Set 13 | lar gerd
# City not found. Skipping...
# Processing Record 35 of Set 13 | vysokaya gora
# Processing Record 36 of Set 13 | sillamae
# Processing Record 37 of Set 13 | ballina
# Processing Record 38 of Set 13 | molokovo
# Processing Record 39 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 13 | siteki
# Processing Record 41 of Set 13 | terrace
# Processing Record 42 of Set 13 | hongjiang
# Processing Record 43 of Set 13 | byron bay
# Processing Record 44 of Set 13 | whittlesea
# Processing Record 45 of Set 13 | nevers
# Processing Record 46 of Set 13 | ust-omchug
# Processing Record 47 of Set 13 | civitanova marche
# Processing Record 48 of Set 13 | liuli
# Processing Record 49 of Set 13 | sosnovo-ozerskoye
# Processing Record 50 of Set 13 | tabuk
# Processing Record 1 of Set 14 | buchanan
# Processing Record 2 of Set 14 | brockville
# Processing Record 3 of Set 14 | pitkyaranta
# Processing Record 4 of Set 14 | taloqan
# Processing Record 5 of Set 14 | barhi
# Processing Record 6 of Set 14 | kysyl-syr
# Processing Record 7 of Set 14 | montepuez
# Processing Record 8 of Set 14 | alice springs
# Processing Record 9 of Set 14 | pacific grove
# Processing Record 10 of Set 14 | katobu
# Processing Record 11 of Set 14 | requena
# Processing Record 12 of Set 14 | ponta delgada
# Processing Record 13 of Set 14 | san ramon
# Processing Record 14 of Set 14 | bradeanu
# Processing Record 15 of Set 14 | waitara
# Processing Record 16 of Set 14 | burriana
# Processing Record 17 of Set 14 | labuhan
# Processing Record 18 of Set 14 | ahipara
# Processing Record 19 of Set 14 | burdeos
# Processing Record 20 of Set 14 | vyazemskiy
# Processing Record 21 of Set 14 | narsimhapur
# Processing Record 22 of Set 14 | bhainsdehi
# Processing Record 23 of Set 14 | inhambane
# Processing Record 24 of Set 14 | bonavista
# Processing Record 25 of Set 14 | adelaide
# Processing Record 26 of Set 14 | tartagal
# Processing Record 27 of Set 14 | mauganj
# Processing Record 28 of Set 14 | aktash
# Processing Record 29 of Set 14 | nome
# Processing Record 30 of Set 14 | elizabeth city
# Processing Record 31 of Set 14 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 32 of Set 14 | asmara
# Processing Record 33 of Set 14 | karonga
# Processing Record 34 of Set 14 | castricum
# Processing Record 35 of Set 14 | faridpur
# Processing Record 36 of Set 14 | svetlyy
# Processing Record 37 of Set 14 | abonnema
# Processing Record 38 of Set 14 | korla
# Processing Record 39 of Set 14 | sovetskiy
# Processing Record 40 of Set 14 | herk-de-stad
# Processing Record 41 of Set 14 | hobyo
# Processing Record 42 of Set 14 | porto novo
# Processing Record 43 of Set 14 | chitral
# Processing Record 44 of Set 14 | kanniyakumari
# Processing Record 45 of Set 14 | keflavik
# Processing Record 46 of Set 14 | livramento
# Processing Record 47 of Set 14 | tulun
# Processing Record 48 of Set 14 | homer
# Processing Record 49 of Set 14 | evensk
# Processing Record 50 of Set 14 | bereda
# Processing Record 1 of Set 15 | beaverlodge
# Processing Record 2 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 15 | santa marta
# Processing Record 4 of Set 15 | svetlaya
# Processing Record 5 of Set 15 | mnogovershinnyy
# Processing Record 6 of Set 15 | siguiri
# Processing Record 7 of Set 15 | maragogi
# Processing Record 8 of Set 15 | cesenatico
# Processing Record 9 of Set 15 | mahibadhoo
# Processing Record 10 of Set 15 | bethanien
# Processing Record 11 of Set 15 | bubaque
# Processing Record 12 of Set 15 | naryan-mar
# Processing Record 13 of Set 15 | siniscola
# Processing Record 14 of Set 15 | kinablangan
# Processing Record 15 of Set 15 | pangnirtung
# Processing Record 16 of Set 15 | porto
# Processing Record 17 of Set 15 | rybinsk
# Processing Record 18 of Set 15 | brewster
# Processing Record 19 of Set 15 | marienburg
# Processing Record 20 of Set 15 | myskhako
# Processing Record 21 of Set 15 | quelimane
# Processing Record 22 of Set 15 | juneau
# Processing Record 23 of Set 15 | saint-paul
# Processing Record 24 of Set 15 | gashua
# Processing Record 25 of Set 15 | buraydah
# Processing Record 26 of Set 15 | mundwa
# Processing Record 27 of Set 15 | santiago del estero
# Processing Record 28 of Set 15 | tromso
# Processing Record 29 of Set 15 | dicabisagan
# Processing Record 30 of Set 15 | jega
# Processing Record 31 of Set 15 | paamiut
# Processing Record 32 of Set 15 | tete
# Processing Record 33 of Set 15 | aguililla
# Processing Record 34 of Set 15 | mae hong son
# Processing Record 35 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 15 | alcanena
# Processing Record 37 of Set 15 | pasighat
# Processing Record 38 of Set 15 | puebloviejo
# Processing Record 39 of Set 15 | burica
# City not found. Skipping...
# Processing Record 40 of Set 15 | ishinomaki
# Processing Record 41 of Set 15 | yilan
# Processing Record 42 of Set 15 | geldrop
# Processing Record 43 of Set 15 | dunhua
# Processing Record 44 of Set 15 | asekeyevo
# Processing Record 45 of Set 15 | praya
# Processing Record 46 of Set 15 | porto murtinho
# Processing Record 47 of Set 15 | buta
# Processing Record 48 of Set 15 | taksimo
# Processing Record 49 of Set 15 | adeje
# Processing Record 50 of Set 15 | suruc
# Processing Record 1 of Set 16 | port augusta
# Processing Record 2 of Set 16 | agadir
# Processing Record 3 of Set 16 | mmathubudukwane
# Processing Record 4 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 16 | ucluelet
# Processing Record 6 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 16 | shimoda
# Processing Record 8 of Set 16 | massakory
# Processing Record 9 of Set 16 | redlands
# Processing Record 10 of Set 16 | mirador
# Processing Record 11 of Set 16 | maldonado
# Processing Record 12 of Set 16 | tilichiki
# Processing Record 13 of Set 16 | vestbygda
# City not found. Skipping...
# Processing Record 14 of Set 16 | nha trang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 708

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     74.12        91         100
# 1         Hermanus      ZA -34.4187   19.2345     58.80        83         100
# 2       San Andres      CO  12.5847  -81.7006     82.24        77          52
# 3            Kashi      CN  39.4547   75.9797     17.37        25          68
# 4    Khryashchevka      RU  53.8119   49.0916     17.13        88          42
# 5        Ostrovnoy      RU  68.0531   39.5131     23.56        89         100
# 6       Chokurdakh      RU  70.6333  147.9167     -0.94        96         100
# 7             Chuy      UY -33.6971  -53.4616     69.10        91          32
# 8            Bluff      NZ -46.6000  168.3333     50.81        64          40
# 9     Longyearbyen      SJ  78.2186   15.6401     35.44        80          75
#
#    Wind Speed Current Description
# 0       20.56     overcast clouds
# 1        2.17     overcast clouds
# 2       18.14       broken clouds
# 3        0.65       broken clouds
# 4        6.62    scattered clouds
# 5        6.76     overcast clouds
# 6        9.19          light snow
# 7       13.73    scattered clouds
# 8       20.11    scattered clouds
# 9        8.05          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     74.12        91         100
# 1         Hermanus      ZA -34.4187   19.2345     58.80        83         100
# 2       San Andres      CO  12.5847  -81.7006     82.24        77          52
# 3            Kashi      CN  39.4547   75.9797     17.37        25          68
# 4    Khryashchevka      RU  53.8119   49.0916     17.13        88          42
# 5        Ostrovnoy      RU  68.0531   39.5131     23.56        89         100
# 6       Chokurdakh      RU  70.6333  147.9167     -0.94        96         100
# 7             Chuy      UY -33.6971  -53.4616     69.10        91          32
# 8            Bluff      NZ -46.6000  168.3333     50.81        64          40
# 9     Longyearbyen      SJ  78.2186   15.6401     35.44        80          75
#
#    Wind Speed Current Description
# 0       20.56     overcast clouds
# 1        2.17     overcast clouds
# 2       18.14       broken clouds
# 3        0.65       broken clouds
# 4        6.62    scattered clouds
# 5        6.76     overcast clouds
# 6        9.19          light snow
# 7       13.73    scattered clouds
# 8       20.11    scattered clouds
# 9        8.05          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
